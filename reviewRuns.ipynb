# %%
import mlflow
import mlflow.xgboost
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# silence some unnecessary messages caused by great expectations
import warnings
warnings.filterwarnings('ignore')

# check out the existing model runs
all_runs = mlflow.search_runs(search_all_experiments=True)
print(all_runs)
# Out:
#                               run_id experiment_id    status  \
# 0   700055d3d3b84e13966d319f84d6064d             1  FINISHED
# 1   58131117a5824f65b956856f9a8dd9ad             1  FINISHED
# 2   e312f61b45ae4f27aa6d9f5a07b89956             1  FINISHED
# 3   09e3a508f55f42ec9b96b77753539656             1  FINISHED
# 4   6c9fab0075ff444d95e534f6727de14a             1  FINISHED
# 5   4a2d7f8cc8e34fd5b54f8600cddc2c71             1  FINISHED
# 6   83105d4b12b745b0bfcb33305cb4cdd5             1  FINISHED
# 7   3c8d643a702a460a8abbecf35b00ed99             1  FINISHED
# 8   d8f32ef852704a08991d87c4ec650f3a             1  FINISHED
# 9   470edc4f79e94947a1c8857ca0b7a390             1  FINISHED
# 10  1f638f01b4d34deaae332a6595ff77c4             1  FINISHED
# 11  6a3d75a3966d49fe94751bab4e9df7b7             1  FINISHED
# 12  0e1adde3f3cf4807ab3df16318f1353b             1  FINISHED
# 13  c421f217b48f40ceb0c684e113f175f5             1  FINISHED
# 14  822422dee16846989ab4b75b59eb8f97             1  FINISHED
# 15  32f0cefd409f406bbca5eb986e748c10             1  FINISHED
# 16  340828f8f817459ab7428d94db4f54a1             1  FINISHED
# 17  83f81e434d474e4eb30b4619134d8dac             1  FINISHED
# 18  2bbeb72b7efa4830909e39858a98489f             1  FINISHED
# 19  dfabbfd58ee4419e97dc5e96f9e1d208             1  FINISHED
# 20  c60737c87112491fb916af88c6f6ae72             1  FINISHED
# 21  3b5547f345d542e99c65ccbfda77a84a             1  FINISHED
# 22  6253b59a2a6b496a8fc92c1fa6b2772e             1  FINISHED
# 23  15c2838176bf4760ba8b02fe5c6700c1             1  FINISHED
# 24  af629a59f0144e639fdb7a81865d8e5a             1  FINISHED
# 25  ecc1c408e58445feabec7b511c7c92ea             1  FINISHED
# 26  b36336c71dfc489cb9359f111528f580             1  FINISHED
# 27  62f775126cc1498f9b56311fd0e7b8d1             1  FINISHED
# 28  6a45b1d5f15a443bbd2c847e8268c9fb             1  FINISHED
# 29  3dda9d58a1ef47ff87bf949f601a34ae             1  FINISHED
# 30  a9b85aa62b7544fd8691de511b08e633             1  FINISHED
# 31  61b68169f1b44feb93e1bc5345debc1c             1  FINISHED
# 32  48b2a871b4e14864800a365bfa308bf4             1  FINISHED
# 33  028f9837769a4594afb347ba88bd9f43             1  FINISHED
# 34  e781ea8706ec4ac0aab37a0945364030             1  FINISHED
# 35  2099da9c6a614d4996abf0d8af888e65             1  FINISHED
# 36  f5047f7a6c4948ebbad69c2e5c0ce6b7             1  FINISHED
# 37  70db549e181d4174b751f891d536d3a5             1  FINISHED
# 38  5903bd23f7c34588a3f57fe35860ee79             1  FINISHED
# 39  a9a7d3e2de284b1784c30e679fc32fd8             1  FINISHED
#
#                                          artifact_uri  \
# 0   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 1   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 2   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 3   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 4   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 5   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 6   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 7   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 8   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 9   file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 10  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 11  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 12  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 13  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 14  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 15  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 16  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 17  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 18  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 19  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 20  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 21  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 22  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 23  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 24  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 25  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 26  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 27  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 28  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 29  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 30  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 31  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 32  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 33  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 34  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 35  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 36  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 37  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 38  file:C:/Users/mseitz3/OneDrive - DXC Productio...
# 39  file:C:/Users/mseitz3/OneDrive - DXC Productio...
#
#                          start_time                         end_time  \
# 0  2026-03-28 21:54:45.048000+00:00 2026-03-28 21:54:54.027000+00:00
# 1  2026-03-28 21:54:36.557000+00:00 2026-03-28 21:54:45.030000+00:00
# 2  2026-03-28 21:54:29.563000+00:00 2026-03-28 21:54:36.538000+00:00
# 3  2026-03-28 21:54:22.906000+00:00 2026-03-28 21:54:29.549000+00:00
# 4  2026-03-28 21:53:53.726000+00:00 2026-03-28 21:54:02.449000+00:00
# 5  2026-03-28 21:53:44.379000+00:00 2026-03-28 21:53:53.871000+00:00
# 6  2026-03-28 21:53:43.516000+00:00 2026-03-28 21:53:53.695000+00:00
# 7  2026-03-28 21:53:35.692000+00:00 2026-03-28 21:53:43.489000+00:00
# 8  2026-03-28 21:53:33.889000+00:00 2026-03-28 21:53:44.361000+00:00
# 9  2026-03-28 21:53:27.035000+00:00 2026-03-28 21:53:35.658000+00:00
# 10 2026-03-28 21:53:25.519000+00:00 2026-03-28 21:53:33.876000+00:00
# 11 2026-03-28 21:53:19.207000+00:00 2026-03-28 21:53:25.505000+00:00
# 12 2026-03-28 21:52:38.123000+00:00 2026-03-28 21:52:46.920000+00:00
# 13 2026-03-28 21:52:31.587000+00:00 2026-03-28 21:52:38.111000+00:00
# 14 2026-03-28 21:52:26.243000+00:00 2026-03-28 21:52:31.572000+00:00
# 15 2026-03-28 21:52:18.811000+00:00 2026-03-28 21:52:26.225000+00:00
# 16 2026-03-28 21:46:27.277000+00:00 2026-03-28 21:46:33.702000+00:00
# 17 2026-03-28 21:46:21.007000+00:00 2026-03-28 21:46:27.263000+00:00
# 18 2026-03-28 21:46:15.631000+00:00 2026-03-28 21:46:20.994000+00:00
# 19 2026-03-28 21:46:07.762000+00:00 2026-03-28 21:46:15.616000+00:00
# 20 2026-03-28 21:44:33.236000+00:00 2026-03-28 21:44:39.594000+00:00
# 21 2026-03-28 21:44:26.607000+00:00 2026-03-28 21:44:33.225000+00:00
# 22 2026-03-28 21:44:21.234000+00:00 2026-03-28 21:44:26.594000+00:00
# 23 2026-03-28 21:44:14.530000+00:00 2026-03-28 21:44:21.222000+00:00
# 24 2026-03-28 21:43:49.113000+00:00 2026-03-28 21:43:55.479000+00:00
# 25 2026-03-28 21:43:42.452000+00:00 2026-03-28 21:43:49.101000+00:00
# 26 2026-03-28 21:43:37.053000+00:00 2026-03-28 21:43:42.440000+00:00
# 27 2026-03-28 21:43:22.685000+00:00 2026-03-28 21:43:37.042000+00:00
# 28 2026-03-28 21:35:37.121000+00:00 2026-03-28 21:35:44.087000+00:00
# 29 2026-03-28 21:35:30.483000+00:00 2026-03-28 21:35:37.107000+00:00
# 30 2026-03-28 21:35:25.428000+00:00 2026-03-28 21:35:30.470000+00:00
# 31 2026-03-28 21:35:18.074000+00:00 2026-03-28 21:35:25.415000+00:00
# 32 2026-03-28 21:24:22.988000+00:00 2026-03-28 21:24:29.676000+00:00
# 33 2026-03-28 21:24:16.315000+00:00 2026-03-28 21:24:22.975000+00:00
# 34 2026-03-28 21:24:10.438000+00:00 2026-03-28 21:24:16.301000+00:00
# 35 2026-03-28 21:24:02.285000+00:00 2026-03-28 21:24:10.422000+00:00
# 36 2026-03-28 21:08:08.961000+00:00 2026-03-28 21:08:15.713000+00:00
# 37 2026-03-28 21:08:02.205000+00:00 2026-03-28 21:08:08.948000+00:00
# 38 2026-03-28 21:07:56.625000+00:00 2026-03-28 21:08:02.194000+00:00
# 39 2026-03-28 21:07:46.084000+00:00 2026-03-28 21:07:56.613000+00:00
#
#     metrics.mae  metrics.r2  metrics.rmse params.train_samples  ...  \
# 0      0.333102    0.799067      0.513132                16512  ...
# 1      0.333078    0.799001      0.513217                16512  ...
# 2      0.419360    0.713127      0.613124                16512  ...
# 3      0.533200    0.575788      0.745581                16512  ...
# 4      0.333102    0.799067      0.513132                16512  ...
# 5      0.333102    0.799067      0.513132                16512  ...
# 6      0.333078    0.799001      0.513217                16512  ...
# 7      0.419360    0.713127      0.613124                16512  ...
# 8      0.333078    0.799001      0.513217                16512  ...
# 9      0.533200    0.575788      0.745581                16512  ...
# 10     0.419360    0.713127      0.613124                16512  ...
# 11     0.533200    0.575788      0.745581                16512  ...
# 12     0.333102    0.799067      0.513132                16512  ...
# 13     0.333078    0.799001      0.513217                16512  ...
# 14     0.419360    0.713127      0.613124                16512  ...
# 15     0.533200    0.575788      0.745581                16512  ...
# 16     0.333102    0.799067      0.513132                16512  ...
# 17     0.333078    0.799001      0.513217                16512  ...
# 18     0.419360    0.713127      0.613124                16512  ...
# 19     0.533200    0.575788      0.745581                16512  ...
# 20     0.333102    0.799067      0.513132                16512  ...
# 21     0.333078    0.799001      0.513217                16512  ...
# 22     0.419360    0.713127      0.613124                16512  ...
# 23     0.533200    0.575788      0.745581                16512  ...
# 24     0.333102    0.799067      0.513132                16512  ...
# 25     0.333078    0.799001      0.513217                16512  ...
# 26     0.419360    0.713127      0.613124                16512  ...
# 27     0.533200    0.575788      0.745581                16512  ...
# 28     0.354754    0.777431      0.540053                16512  ...
# 29     0.330663    0.800792      0.510924                16512  ...
# 30     0.419360    0.713127      0.613124                16512  ...
# 31     0.533200    0.575788      0.745581                16512  ...
# 32     0.333102    0.799067      0.513132                16512  ...
# 33     0.333078    0.799001      0.513217                16512  ...
# 34     0.419666    0.711180      0.615201                16512  ...
# 35     0.533200    0.575788      0.745581                16512  ...
# 36     0.333102    0.799067      0.513132                16512  ...
# 37     0.333078    0.799001      0.513217                16512  ...
# 38     0.419666    0.711180      0.615201                16512  ...
# 39     0.533200    0.575788      0.745581                16512  ...
#
#         params.dataset       params.preprocessing params.n_features  \
# 0   California Housing  StandardScaler (for demo)                 8
# 1   California Housing                       None                 8
# 2   California Housing                       None                 8
# 3   California Housing                       None                 8
# 4   California Housing  StandardScaler (for demo)                 8
# 5   California Housing  StandardScaler (for demo)                 8
# 6   California Housing                       None                 8
# 7   California Housing                       None                 8
# 8   California Housing                       None                 8
# 9   California Housing                       None                 8
# 10  California Housing                       None                 8
# 11  California Housing                       None                 8
# 12  California Housing  StandardScaler (for demo)                 8
# 13  California Housing                       None                 8
# 14  California Housing                       None                 8
# 15  California Housing                       None                 8
# 16  California Housing  StandardScaler (for demo)                 8
# 17  California Housing                       None                 8
# 18  California Housing                       None                 8
# 19  California Housing                       None                 8
# 20  California Housing  StandardScaler (for demo)                 8
# 21  California Housing                       None                 8
# 22  California Housing                       None                 8
# 23  California Housing                       None                 8
# 24  California Housing  StandardScaler (for demo)                 8
# 25  California Housing                       None                 8
# 26  California Housing                       None                 8
# 27  California Housing                       None                 8
# 28  California Housing             StandardScaler                 8
# 29  California Housing                       None                 8
# 30  California Housing                       None                 8
# 31  California Housing                       None                 8
# 32  California Housing             StandardScaler                 8
# 33  California Housing                       None                 8
# 34  California Housing                       None                 8
# 35  California Housing                       None                 8
# 36  California Housing             StandardScaler                 8
# 37  California Housing                       None                 8
# 38  California Housing                       None                 8
# 39  California Housing                       None                 8
#
#         params.model_type params.min_samples_leaf params.fit_intercept  \
# 0   RandomForestRegressor                       4                 None
# 1   RandomForestRegressor                       4                 None
# 2   DecisionTreeRegressor                      15                 None
# 3        LinearRegression                    None                 True
# 4   RandomForestRegressor                       4                 None
# 5   RandomForestRegressor                       4                 None
# 6   RandomForestRegressor                       4                 None
# 7   DecisionTreeRegressor                      15                 None
# 8   RandomForestRegressor                       4                 None
# 9        LinearRegression                    None                 True
# 10  DecisionTreeRegressor                      15                 None
# 11       LinearRegression                    None                 True
# 12  RandomForestRegressor                       4                 None
# 13  RandomForestRegressor                       4                 None
# 14  DecisionTreeRegressor                      15                 None
# 15       LinearRegression                    None                 True
# 16  RandomForestRegressor                       4                 None
# 17  RandomForestRegressor                       4                 None
# 18  DecisionTreeRegressor                      15                 None
# 19       LinearRegression                    None                 True
# 20  RandomForestRegressor                       4                 None
# 21  RandomForestRegressor                       4                 None
# 22  DecisionTreeRegressor                      15                 None
# 23       LinearRegression                    None                 True
# 24  RandomForestRegressor                       4                 None
# 25  RandomForestRegressor                       4                 None
# 26  DecisionTreeRegressor                      15                 None
# 27       LinearRegression                    None                 True
# 28  RandomForestRegressor                      15                 None
# 29  RandomForestRegressor                       4                 None
# 30  DecisionTreeRegressor                      15                 None
# 31       LinearRegression                    None                 True
# 32  RandomForestRegressor                       4                 None
# 33  RandomForestRegressor                       4                 None
# 34  DecisionTreeRegressor                      10                 None
# 35       LinearRegression                    None                 True
# 36  RandomForestRegressor                       4                 None
# 37  RandomForestRegressor                       4                 None
# 38  DecisionTreeRegressor                      10                 None
# 39       LinearRegression                    None                 True
#
#            tags.mlflow.runName  \
# 0   Random Forest with Scaling
# 1                Random Forest
# 2                Decision Tree
# 3            Linear Regression
# 4   Random Forest with Scaling
# 5   Random Forest with Scaling
# 6                Random Forest
# 7                Decision Tree
# 8                Random Forest
# 9            Linear Regression
# 10               Decision Tree
# 11           Linear Regression
# 12  Random Forest with Scaling
# 13               Random Forest
# 14               Decision Tree
# 15           Linear Regression
# 16  Random Forest with Scaling
# 17               Random Forest
# 18               Decision Tree
# 19           Linear Regression
# 20  Random Forest with Scaling
# 21               Random Forest
# 22               Decision Tree
# 23           Linear Regression
# 24  Random Forest with Scaling
# 25               Random Forest
# 26               Decision Tree
# 27           Linear Regression
# 28  Random Forest with Scaling
# 29               Random Forest
# 30               Decision Tree
# 31           Linear Regression
# 32  Random Forest with Scaling
# 33               Random Forest
# 34               Decision Tree
# 35           Linear Regression
# 36  Random Forest with Scaling
# 37               Random Forest
# 38               Decision Tree
# 39           Linear Regression
#
#                               tags.mlflow.source.name tags.mlflow.user  \
# 0   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 1   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 2   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 3   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 4   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 5   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 6   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 7   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 8   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 9   c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 10  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 11  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 12  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 13  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 14  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 15  c:\Users\mseitz3\OneDrive - DXC Production\sch...          mseitz3
# 16                                            main.py          mseitz3
# 17                                            main.py          mseitz3
# 18                                            main.py          mseitz3
# 19                                            main.py          mseitz3
# 20                                            main.py          mseitz3
# 21                                            main.py          mseitz3
# 22                                            main.py          mseitz3
# 23                                            main.py          mseitz3
# 24                                            main.py          mseitz3
# 25                                            main.py          mseitz3
# 26                                            main.py          mseitz3
# 27                                            main.py          mseitz3
# 28                                            main.py          mseitz3
# 29                                            main.py          mseitz3
# 30                                            main.py          mseitz3
# 31                                            main.py          mseitz3
# 32                                            main.py          mseitz3
# 33                                            main.py          mseitz3
# 34                                            main.py          mseitz3
# 35                                            main.py          mseitz3
# 36                                            main.py          mseitz3
# 37                                            main.py          mseitz3
# 38                                            main.py          mseitz3
# 39                                            main.py          mseitz3
#
#    tags.mlflow.source.type
# 0                    LOCAL
# 1                    LOCAL
# 2                    LOCAL
# 3                    LOCAL
# 4                    LOCAL
# 5                    LOCAL
# 6                    LOCAL
# 7                    LOCAL
# 8                    LOCAL
# 9                    LOCAL
# 10                   LOCAL
# 11                   LOCAL
# 12                   LOCAL
# 13                   LOCAL
# 14                   LOCAL
# 15                   LOCAL
# 16                   LOCAL
# 17                   LOCAL
# 18                   LOCAL
# 19                   LOCAL
# 20                   LOCAL
# 21                   LOCAL
# 22                   LOCAL
# 23                   LOCAL
# 24                   LOCAL
# 25                   LOCAL
# 26                   LOCAL
# 27                   LOCAL
# 28                   LOCAL
# 29                   LOCAL
# 30                   LOCAL
# 31                   LOCAL
# 32                   LOCAL
# 33                   LOCAL
# 34                   LOCAL
# 35                   LOCAL
# 36                   LOCAL
# 37                   LOCAL
# 38                   LOCAL
# 39                   LOCAL
#
# [40 rows x 26 columns]
